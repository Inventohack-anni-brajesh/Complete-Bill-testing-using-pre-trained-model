# %%
# !pip install paddleocr paddlepaddle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=8b371fa89336f989beb5828acb16640e57c6f8a3d652f131fb5498abbd90cb28
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
from paddleocr import PaddleOCR

# Load OCR model
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # English OCR

def extract_text_paddleocr(image_path):
    result = ocr.ocr(image_path, cls=True)
    extracted_text = ""

    for line in result[0]:
        text = line[1][0]
        extracted_text += text + "\n"

    return extracted_text
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 3910/3910 [00:11<00:00, 334.69it/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10000/10000 [00:12<00:00, 796.04it/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# ...

# %%
text = extract_text_paddleocr("/content/bill 7.png")
print(text)
# Out:
# [2025/04/12 10:50:01] ppocr DEBUG: dt_boxes num : 60, elapsed : 0.3109407424926758
# [2025/04/12 10:50:02] ppocr DEBUG: cls num  : 60, elapsed : 0.17647981643676758
# [2025/04/12 10:50:06] ppocr DEBUG: rec_res num  : 60, elapsed : 4.824893951416016
# [COMPANY NAME]
# Tax invoice
# [Address Line 1]
# [INVOICE NUMBER]
# [Address Line 2]
# [DATE]
# [Address Line 3]
# [GST NUMBER]
#  Bill To
# [Customer Name]
# Invoice Date
# 31 Dec 2020
# [Address Line 1]
# Due Date
# 01 Jan 2021
# [Address Line 2]
# Customer GSTN
# [ENTER GST]
# [Phone]
# ID
# Description
# HSN
# Quantity
# Rate
# code
# Amount
# Sale Item #1
# 1
# 5,000.00
#  5,000.00
# 2
# Sale Item #2
# 1
# 4,000.00
#  4,000.00
# 3
# Sale Item #3
# 2
# 1,000.00
#  2,000.00
# Sub total
#  11,000.00
# Thank you for your business!
# Discount
#  0
# Payment Details
# Tax Rate
# 18%
# Account name: COMPANY NAME
# Account number: 9876543210
# Tax
# 1,980.00
# Bank name : ABCD Bank
# IFSC c0de : ABCD123456789
# Shipping
# 0
# ...

# %%
text = extract_text_paddleocr("/content/bill1.jpg")
print(text)
# Out:
# [2025/04/12 11:00:53] ppocr DEBUG: dt_boxes num : 74, elapsed : 0.22244501113891602
# [2025/04/12 11:00:53] ppocr DEBUG: cls num  : 74, elapsed : 0.24945473670959473
# [2025/04/12 11:00:59] ppocr DEBUG: rec_res num  : 74, elapsed : 5.266040086746216
# T
# 7M
# 4Patkcta
# To
# -
# www.twwcratcl.cw.ry
# Filkhoxl.com.my
# Fas
# -100
# TOWER HOTEL
# Guest Information
# Booking D:
# B
# 0005126
# POONMEFUNG
# B Dt:
# 125
# Checkin:
# 06/10/2011
# 07/10/20112:00:00PM
# Check Out:
# 12/10/20112:00:00PM
# HONG KONG
# RoomN:
# 201
# Room Type:
# Family Room
# TTN
# Cilden:
# Adults:
# 1
# Dete
# Description
# Charges
# Payments
# O5/10/11
# O/101
# qy S
# 7/1/2011PSynta
# 150.00
# 05/10/11
# Sun 0/10/2011s Vyntal
# 100.00
# 198.00
# 06/10/11
# Tue 11/1/2011sVKyntal
# Mon 10/10/2011 sPS VKDey Ren1
# 138.00
# 05/10/11
# 710/2011sKHurnta
# 00'26
# 05/10/11
# 45.00
# Total excluding Discourt&Tax
# 797.00
# Discount
# 0.00
# Tax
# 47.82
# Rounding
# 0.02
# FMS44.80
# Paymerts
# RM0.00
# ...

# %%
text = extract_text_paddleocr("/content/bill 2.png")
print(text)
# Out:
# [2025/04/12 11:00:59] ppocr DEBUG: dt_boxes num : 59, elapsed : 0.20740199089050293
# [2025/04/12 11:00:59] ppocr DEBUG: cls num  : 59, elapsed : 0.18283867835998535
# [2025/04/12 11:01:05] ppocr DEBUG: rec_res num  : 59, elapsed : 6.241771459579468
# Raga Pvt Ltd
# Tax Invoice
# 143 south car street
# Invoice Number
# INV2
# Anna Nagar
# Invoice Date
# 04-06-2018
# Madurai - 612897Tamil Nadu,India
# Due Date
# 04-06-2018
# Phone:045225852588
# raga@gmail.com
# GSTIN :33AAAGP0685F1ZH
# Issued To
# Billing & Shipping Address :
# Anu Auto Stores
# Anu Auto Stores
# GSTIN
# 33AQZPS2365E1ZE
# Adyar
# POS
# Tamil Nadu
# Mobile
# 9823561230
# Phone
# 044568798899
# anu@gmail.com
# SN Item Desc HSN/SAC
# Qty
# RateRs
# D/CRs
# Tax
# Amount(Rs)
# 1
# Chakkar
# 3604
# 1
# 250.00
# 25.00GST5%
# 225.00
# Sub Total
# 225.00
# CGST
# 2.50%on
# 225.00
# 5.63
# SGST 2.50 % on
# 225.00
# 5.63
# Total
# 236.26
# Amount (in words)
# Rs Two Hundred and Thirty Six Rupees Twenty Six Paise only
# Notes
# ...

# %%
text = extract_text_paddleocr("/content/bill3.jpg")
print(text)
# Out:
# [2025/04/12 11:01:06] ppocr DEBUG: dt_boxes num : 85, elapsed : 0.614495038986206
# [2025/04/12 11:01:06] ppocr DEBUG: cls num  : 85, elapsed : 0.2541365623474121
# [2025/04/12 11:01:15] ppocr DEBUG: rec_res num  : 85, elapsed : 8.923739671707153
# Tax Invoice
# JMV LPS LIMITED (UNIT-W50)
# Invoice No
# Dated
# W-50SECTOR-11NOIDA
# JMVW50/0001
# 1-Apr-21
# GAUTAM BUDHA NAGAR, UTTAR PRADESH-201301
# Delivery Note
# Mode/Terms of Payment
# TAN:MRTJ01058B
# 30 Days
# GSTIN/UIN:09AACCJ0193L2ZB
# Reference No.& Date.
# Other References
# State Name:Uttar Pradesh,Code:09
# JMVW50/0001 dt.1-Apr-21
# CIN:U93000UP2008PLC034803
# Buyer's Order No.
# Dated
# E-Mail : accounts@jmv.co.in
# BYVERBAL
# 1-Apr-21
# Consignee (Ship to)
# Dispatch Doc No.
# Delivery Note Date
# Dispatched through
# Destination
# By Road
# Greater Noida
# GSTIN/UIN:
# Bill of Lading/LR-RR No.
# Motor Vehicle No.
# State Name:
# Uttar PradeshCode:09
# UP16DT3901
# Buyer (Bill to)
# Terms of Delivery
# Astha Enterprises
# ...

# %%
text = extract_text_paddleocr("/content/bill4.jpg")
print(text)
# Out:
# [2025/04/12 11:01:15] ppocr DEBUG: dt_boxes num : 44, elapsed : 0.21792101860046387
# [2025/04/12 11:01:15] ppocr DEBUG: cls num  : 44, elapsed : 0.14706921577453613
# [2025/04/12 11:01:19] ppocr DEBUG: rec_res num  : 44, elapsed : 3.2073166370391846
# GUJARAT FREIGHT TOOLS
# 123SunriseApartment
# Main Street Sector 5
# Mumbai surburban,Dadra & Nagar
# Haveli and Daman &Diu-396210
# GSTIN:26C0RPP3939N1ZA
# TAX INVOICE
# INVOICE#:55
# DATE:20-Mar-2024
# =BILLEDTO==
# Name:Ronak Panchal
# Items
# Taxable
# HSN
# Total
# +GST
# Rate
# Basic Knit Top SS x1
# 189.52
# 199.00
# NOS
# +5.00%
# Size:5-6Y
# HSN:6109
# Rate:189.52
# Knit Top SS x1 NOS
# 189.52
# 199.00
# Size:5-6Y
# +5.00%
# HSN:6109
# Rate:189.52
# =SUMMARY=
# Taxable Amount
# 379.04
# Add:IGST
# 18.96
# Total Tax
# 18.96
# Total Amount After Tax
# 398.00
# Grand Total:
# 398.00
# Pay using UPI

# %%
text = extract_text_paddleocr("/content/bill5.jpg")
print(text)
# Out:
# [2025/04/12 11:01:19] ppocr DEBUG: dt_boxes num : 111, elapsed : 0.33250904083251953
# [2025/04/12 11:01:19] ppocr DEBUG: cls num  : 111, elapsed : 0.34383201599121094
# [2025/04/12 11:01:28] ppocr DEBUG: rec_res num  : 111, elapsed : 8.402939558029175
# GUJARAT EREIGHT TOOLS
# Manufacturing & Supply of Precision Press Tool & Room Component
# 64, Akshay Industrial Estate
# Tel : 079-25820309
# Near New Cloath Market,
# Web : www.gftools.com
# LOGOTEXT
# Ahmedabad- 38562
# Email : info@gftools.com
# SLOGANHERE
# GSTIN : 24HDE7487RE5RT4
# TAX INVOICE
# ORIGINAL FOR RECIPIENT
# Customer Detail
#  Invoice No.
# GST112020
# Invoice Date
# 04-Mar-2020
# M/S
# Kevin Motors
# Challan No
# 865
# Challan Date
# 03-Mar-2020
# Address
# Chandani Chok, New Delhi, Opposite
# P.O. No.
# 66
# Statue, New Delhiq, Delhi - 110014
# PHONE
# 9372346666
# DELIVERY DATE
# 04-Mar-2020
# Reverse Charge
# No
# GSTIN
# 07AOLCC1206D1ZG
# L.R.No.
# 958
# Due Date
# 19-Mar-2020
# Place of
# Delhi (07)
# ...

# %%
text = extract_text_paddleocr("/content/bill 6.png")
print(text)
# Out:
# [2025/04/12 11:01:28] ppocr DEBUG: dt_boxes num : 60, elapsed : 0.18376612663269043
# [2025/04/12 11:01:28] ppocr DEBUG: cls num  : 60, elapsed : 0.15523004531860352
# [2025/04/12 11:01:32] ppocr DEBUG: rec_res num  : 60, elapsed : 3.8383665084838867
# INVOICE
# SUPPLIER
# Invoice No:
# SVk TRV
# INV-001
# 91 Springboard, Creaticity
# Bill date:
# mall, Yerawada, Pune,
# Maharashtra 411006
# 31May 2022
# pareshhpatil@gmail.com
# Due date:
# 31 May 2022
# 9307691293
# CLIENT
# Rohit Sharma
# CUST-001
# rohit@swipez.in
# 7303885709
# Item
# Sac Code
# Quantity
# Unit Price
# GST
# Total
# Converse All Star
# 6666
# 7
# 1000.00
# 18%
# 1000.00
# Terms & conditions
# SUB TOTAL
# 2000.00
# 1. Lorem Ipsum is simply dummy text of the
# printing.
# CGST@9%
# 90.00
# 2. Text ever since the 1500s, when an
# unknown printer took.
# SGST@9%
# 90.00
# 3. Survived not only five centuries, but also
# TOTAL
# 2,360.00
# the leap into electronic
# 4. Contrary to popular belief, Lorem Ipsum is
# ...

# %%
text = extract_text_paddleocr("/content/bill8.jpg")
print(text)
# Out:
# [2025/04/12 11:01:32] ppocr DEBUG: dt_boxes num : 51, elapsed : 0.22577452659606934
# [2025/04/12 11:01:32] ppocr DEBUG: cls num  : 51, elapsed : 0.17498373985290527
# [2025/04/12 11:01:36] ppocr DEBUG: rec_res num  : 51, elapsed : 3.7482197284698486
# Company Name
# Company
# Logo
# Company Address:ABC Bldg,DEF Street XYZ
# Company Registration ID:AAA-1111/123
# Invoice
# Date:
# 28-08-2019
# Client Name & Address
# Invoice #:
# ABC123
# BBB
# Client ID:
# A2
# PayPal ID:
# abc@def.com
# 123,45678,92
# Payoneer ID:
# GHI@KLM.com
# Description
# Hourly Rate
# Hours
# Amount
# Landing Page Designing
# $
# 55.00
# 5.50
# $
# 30:020
# Plug-ins Installation
# $
# 35.00
# 1.00
# $
# 35.00
# App Creation
# $
# 65.00
# 8.00
# $
# 520.00
# Subtotal
# $857.50
# Tax
# 0%
# $
# Grand Total
# $857.50
# Amount In Words:
# Eight Hundred Fifty Seven Dollars and Fifty Cents
# Thank You For Your Business

# %%
text = extract_text_paddleocr("/content/bill9.png")
print(text)
# Out:
# [2025/04/12 11:01:37] ppocr DEBUG: dt_boxes num : 170, elapsed : 0.604304313659668
# [2025/04/12 11:01:38] ppocr DEBUG: cls num  : 170, elapsed : 0.6303842067718506
# [2025/04/12 11:01:59] ppocr DEBUG: rec_res num  : 170, elapsed : 21.62775182723999
# Bill of Lading
# freightsimple
# PRO Number 123456789
# NOT NEGOTIABLE
# DO NOT MODIFY.TO MAKE CHANGES VISIT FREIGHTSIMPLE.COM
# Customer Service 1-780-660-4807 or hello@freightsimple.com
# KINDERSLEY
# Transport Ltd.
# 123456789
# DATE23Jan. 2020
# a Member of the S/emens
# Transportation Group Inc
# SHIPPER INFORMATION
# BOL Number
# Shipper's Number
# Shipper Name (FROM)
# ABCDEF
# 1234567
# Devinci Cycles
# Purchase Order #
# Quote Number
# Street Address
# 7654321
# XYZ
# 1555 Manic Rue
# Freight Charges (*Check One)
# Enter Info
# City/Town
# Province/State
# Below
# Chicoutimi
# QC
# Prepaid
# Collect
#  Third Party
# +...
# Postal / Zip Code
# G7K1G8
# Phone#
# 5673494915
# *If not marked Shipment will move COLLECT
# ...

# %%
text = extract_text_paddleocr("/content/bill10.png")
print(text)
# Out:
# [2025/04/12 11:02:00] ppocr DEBUG: dt_boxes num : 111, elapsed : 0.4260988235473633
# [2025/04/12 11:02:00] ppocr DEBUG: cls num  : 111, elapsed : 0.3837921619415283
# [2025/04/12 11:02:08] ppocr DEBUG: rec_res num  : 111, elapsed : 7.743067979812622
# ORIGINALFORRECIPIENT
# TAX INVOICE
# Logo
# 3MXYZ
# Registered Office:
# Tel-No:
# CIN:
# 3MXYZ,CFVGB,KARNATAKA,KARNATAKA,560023
# Tel-No:
# GSTIN:2
# 00
# IRN:
# def8077c6256c7742085a71875aad0d79207b2e260581875307d2cd519
# a7e57f
# Tax is Payable on Reverse
# No
# Transportation Mode:
# Charge:
# Invoice Serial Number
# 234694KF48
# Veh.No:
# Invoice Date:
# 02-07-2020
# Date & Time of Supply
# Invoice Currency Code
# INR
# Place of Supply
# Karnataka
# Details of Customer Bill to
# Details of Consignee (Ship to)
# Name:
# HDFC
# Name:
# leg name15
# Address:
# 234,Karnataka
# Address:
# amr tech park
# State Name:
# DELHI
# State Name:
# KARNATAKA
# State Code:
# 07
# State Code:
# 29
# GSTIN:
# 29
# IZS
# GSTIN:
# 2
# ZW
# S.
# ...
